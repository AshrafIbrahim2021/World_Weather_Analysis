# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | barentsburg
# Processing Record 3 of Set 1 | konstantinovka
# Processing Record 4 of Set 1 | ouango
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | tillabery
# Processing Record 9 of Set 1 | yerbogachen
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | vardo
# Processing Record 16 of Set 1 | havoysund
# Processing Record 17 of Set 1 | faya
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | hay river
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | khromtau
# Processing Record 23 of Set 1 | pocone
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | tucumcari
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | kabalo
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | mugumu
# Processing Record 35 of Set 1 | ancud
# Processing Record 36 of Set 1 | moerai
# Processing Record 37 of Set 1 | okhotsk
# Processing Record 38 of Set 1 | gueugnon
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | lolua
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | dargaville
# Processing Record 46 of Set 1 | moa
# Processing Record 47 of Set 1 | gerash
# Processing Record 48 of Set 1 | mazagao
# Processing Record 49 of Set 1 | beringovskiy
# Processing Record 50 of Set 1 | emporia
# Processing Record 1 of Set 2 | artyk
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | uspenka
# Processing Record 4 of Set 2 | paris
# Processing Record 5 of Set 2 | barcelos
# Processing Record 6 of Set 2 | talnakh
# Processing Record 7 of Set 2 | manono
# Processing Record 8 of Set 2 | antofagasta
# Processing Record 9 of Set 2 | naze
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | viedma
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | presidencia roque saenz pena
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | kota kinabalu
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | sinnamary
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | santa fe
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | abu dhabi
# Processing Record 24 of Set 2 | belushya guba
# Processing Record 25 of Set 2 | bolondron
# Processing Record 26 of Set 2 | mys shmidta
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | armacao dos buzios
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | san alberto
# Processing Record 31 of Set 2 | monrovia
# Processing Record 32 of Set 2 | taolanaro
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | fairbanks
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | balabac
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | kajaani
# Processing Record 44 of Set 2 | nchelenge
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | jiwani
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | neuquen
# Processing Record 49 of Set 2 | troitskoye
# Processing Record 50 of Set 2 | dubai
# Processing Record 1 of Set 3 | namatanai
# Processing Record 2 of Set 3 | the valley
# Processing Record 3 of Set 3 | george town
# Processing Record 4 of Set 3 | cidreira
# Processing Record 5 of Set 3 | goundam
# Processing Record 6 of Set 3 | vestmannaeyjar
# Processing Record 7 of Set 3 | iquique
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | prescott
# Processing Record 10 of Set 3 | nizhneyansk
# Processing Record 11 of Set 3 | corumba
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | sao felix do xingu
# Processing Record 17 of Set 3 | lithgow
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | rawah
# Processing Record 20 of Set 3 | toliary
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | guymon
# Processing Record 23 of Set 3 | oranjemund
# Processing Record 24 of Set 3 | bambanglipuro
# Processing Record 25 of Set 3 | brunico
# Processing Record 26 of Set 3 | da nang
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | aflu
# Processing Record 29 of Set 3 | hirara
# Processing Record 30 of Set 3 | lagoa
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | egvekinot
# Processing Record 33 of Set 3 | acaponeta
# Processing Record 34 of Set 3 | prabumulih
# Processing Record 35 of Set 3 | okakarara
# Processing Record 36 of Set 3 | nyaunglebin
# Processing Record 37 of Set 3 | busselton
# Processing Record 38 of Set 3 | la libertad
# Processing Record 39 of Set 3 | le port
# Processing Record 40 of Set 3 | laguna
# Processing Record 41 of Set 3 | nuuk
# Processing Record 42 of Set 3 | poopo
# Processing Record 43 of Set 3 | nanakuli
# Processing Record 44 of Set 3 | tlacotepec
# Processing Record 45 of Set 3 | ngorongoro
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | bethel
# Processing Record 50 of Set 3 | pathein
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | vostok
# Processing Record 4 of Set 4 | richards bay
# Processing Record 5 of Set 4 | beloha
# Processing Record 6 of Set 4 | shelburne
# Processing Record 7 of Set 4 | nizhniy tsasuchey
# Processing Record 8 of Set 4 | orhei
# Processing Record 9 of Set 4 | campos
# Processing Record 10 of Set 4 | kuche
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | kampot
# Processing Record 13 of Set 4 | pangai
# Processing Record 14 of Set 4 | yaan
# Processing Record 15 of Set 4 | manassas park
# Processing Record 16 of Set 4 | torbay
# Processing Record 17 of Set 4 | khavarion
# Processing Record 18 of Set 4 | causapscal
# Processing Record 19 of Set 4 | baruun-urt
# Processing Record 20 of Set 4 | corrente
# Processing Record 21 of Set 4 | qandala
# Processing Record 22 of Set 4 | guerrero negro
# Processing Record 23 of Set 4 | aksu
# Processing Record 24 of Set 4 | iralaya
# Processing Record 25 of Set 4 | arlington
# Processing Record 26 of Set 4 | ust-nera
# Processing Record 27 of Set 4 | yeppoon
# Processing Record 28 of Set 4 | litovko
# Processing Record 29 of Set 4 | lethem
# Processing Record 30 of Set 4 | bridlington
# Processing Record 31 of Set 4 | marrakesh
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | sarangani
# Processing Record 34 of Set 4 | wuan
# Processing Record 35 of Set 4 | tumannyy
# Processing Record 36 of Set 4 | cam ranh
# Processing Record 37 of Set 4 | tsogni
# Processing Record 38 of Set 4 | umm kaddadah
# Processing Record 39 of Set 4 | placido de castro
# Processing Record 40 of Set 4 | samusu
# Processing Record 41 of Set 4 | palabuhanratu
# Processing Record 42 of Set 4 | gogrial
# Processing Record 43 of Set 4 | chontalpa
# Processing Record 44 of Set 4 | waitati
# Processing Record 45 of Set 4 | sept-iles
# Processing Record 46 of Set 4 | barbar
# Processing Record 47 of Set 4 | port hedland
# Processing Record 48 of Set 4 | sentyabrskiy
# Processing Record 49 of Set 4 | bakel
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | umzimvubu
# Processing Record 2 of Set 5 | acapulco
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | nouadhibou
# Processing Record 5 of Set 5 | amderma
# Processing Record 6 of Set 5 | sangar
# Processing Record 7 of Set 5 | port-gentil
# Processing Record 8 of Set 5 | pangnirtung
# Processing Record 9 of Set 5 | fevralsk
# Processing Record 10 of Set 5 | moose factory
# Processing Record 11 of Set 5 | auki
# Processing Record 12 of Set 5 | belaya gora
# Processing Record 13 of Set 5 | yazd
# Processing Record 14 of Set 5 | qaanaaq
# Processing Record 15 of Set 5 | asfi
# Processing Record 16 of Set 5 | takhatpur
# Processing Record 17 of Set 5 | quarai
# Processing Record 18 of Set 5 | ogembo
# Processing Record 19 of Set 5 | oksfjord
# Processing Record 20 of Set 5 | kavaratti
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | shebunino
# Processing Record 25 of Set 5 | terney
# Processing Record 26 of Set 5 | totness
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | mahajanga
# Processing Record 29 of Set 5 | balkanabat
# Processing Record 30 of Set 5 | rio gallegos
# Processing Record 31 of Set 5 | marsabit
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | shingu
# Processing Record 34 of Set 5 | charters towers
# Processing Record 35 of Set 5 | paluan
# Processing Record 36 of Set 5 | geraldton
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | joshimath
# Processing Record 39 of Set 5 | kibala
# Processing Record 40 of Set 5 | umm lajj
# Processing Record 41 of Set 5 | rio cuarto
# Processing Record 42 of Set 5 | marawi
# Processing Record 43 of Set 5 | nioki
# Processing Record 44 of Set 5 | urengoy
# Processing Record 45 of Set 5 | anta
# Processing Record 46 of Set 5 | soria
# Processing Record 47 of Set 5 | srednekolymsk
# Processing Record 48 of Set 5 | bathsheba
# Processing Record 49 of Set 5 | butaritari
# Processing Record 50 of Set 5 | karaul
# Processing Record 1 of Set 6 | victoria
# Processing Record 2 of Set 6 | shreveport
# Processing Record 3 of Set 6 | moyobamba
# Processing Record 4 of Set 6 | kashi
# Processing Record 5 of Set 6 | miranorte
# Processing Record 6 of Set 6 | barrow
# Processing Record 7 of Set 6 | huarmey
# Processing Record 8 of Set 6 | beira
# Processing Record 9 of Set 6 | carroll
# Processing Record 10 of Set 6 | kodinar
# Processing Record 11 of Set 6 | waingapu
# Processing Record 12 of Set 6 | severodvinsk
# Processing Record 13 of Set 6 | napasar
# Processing Record 14 of Set 6 | mehamn
# Processing Record 15 of Set 6 | los llanos de aridane
# Processing Record 16 of Set 6 | ayorou
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | mareeba
# Processing Record 19 of Set 6 | surt
# Processing Record 20 of Set 6 | karratha
# Processing Record 21 of Set 6 | la asuncion
# Processing Record 22 of Set 6 | saint-ambroise
# Processing Record 23 of Set 6 | tuku
# Processing Record 24 of Set 6 | binzhou
# Processing Record 25 of Set 6 | muskogee
# Processing Record 26 of Set 6 | temirtau
# Processing Record 27 of Set 6 | aasiaat
# Processing Record 28 of Set 6 | yulara
# Processing Record 29 of Set 6 | poso
# Processing Record 30 of Set 6 | lithakia
# Processing Record 31 of Set 6 | muzhi
# Processing Record 32 of Set 6 | erzincan
# Processing Record 33 of Set 6 | mizoch
# Processing Record 34 of Set 6 | damara
# Processing Record 35 of Set 6 | pesaro
# Processing Record 36 of Set 6 | port moresby
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | nantucket
# Processing Record 40 of Set 6 | touros
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | pemangkat
# Processing Record 43 of Set 6 | upata
# Processing Record 44 of Set 6 | kaitangata
# Processing Record 45 of Set 6 | pozoblanco
# Processing Record 46 of Set 6 | henties bay
# Processing Record 47 of Set 6 | wladyslawowo
# Processing Record 48 of Set 6 | arman
# Processing Record 49 of Set 6 | new waterford
# Processing Record 50 of Set 6 | westport
# Processing Record 1 of Set 7 | tsihombe
# Processing Record 2 of Set 7 | sisimiut
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | rio do sul
# Processing Record 5 of Set 7 | illoqqortoormiut
# Processing Record 6 of Set 7 | agadez
# Processing Record 7 of Set 7 | nome
# Processing Record 8 of Set 7 | santa vitoria do palmar
# Processing Record 9 of Set 7 | homer
# Processing Record 10 of Set 7 | broome
# Processing Record 11 of Set 7 | mugango
# Processing Record 12 of Set 7 | tralee
# Processing Record 13 of Set 7 | verkh-usugli
# Processing Record 14 of Set 7 | falealupo
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | hualmay
# Processing Record 17 of Set 7 | suratgarh
# Processing Record 18 of Set 7 | sataua
# Processing Record 19 of Set 7 | skagastrond
# Processing Record 20 of Set 7 | koulikoro
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | paita
# Processing Record 23 of Set 7 | haibowan
# Processing Record 24 of Set 7 | maues
# Processing Record 25 of Set 7 | inirida
# Processing Record 26 of Set 7 | samfya
# Processing Record 27 of Set 7 | saleaula
# Processing Record 28 of Set 7 | suntar
# Processing Record 29 of Set 7 | duku
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | esil
# Processing Record 32 of Set 7 | quatre cocos
# Processing Record 33 of Set 7 | pacific grove
# Processing Record 34 of Set 7 | goderich
# Processing Record 35 of Set 7 | macaboboni
# Processing Record 36 of Set 7 | leningradskiy
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | luau
# Processing Record 39 of Set 7 | seoul
# Processing Record 40 of Set 7 | okha
# Processing Record 41 of Set 7 | zarubino
# Processing Record 42 of Set 7 | manjacaze
# Processing Record 43 of Set 7 | ola
# Processing Record 44 of Set 7 | chengam
# Processing Record 45 of Set 7 | ust-tsilma
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | trebisov
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | hamilton
# Processing Record 50 of Set 7 | tecoanapa
# Processing Record 1 of Set 8 | monteiro
# Processing Record 2 of Set 8 | sayyan
# Processing Record 3 of Set 8 | raudeberg
# Processing Record 4 of Set 8 | brae
# Processing Record 5 of Set 8 | caibarien
# Processing Record 6 of Set 8 | khatanga
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | kungurtug
# Processing Record 9 of Set 8 | luxor
# Processing Record 10 of Set 8 | berlevag
# Processing Record 11 of Set 8 | qaqortoq
# Processing Record 12 of Set 8 | manokwari
# Processing Record 13 of Set 8 | georgiyevka
# Processing Record 14 of Set 8 | vila
# Processing Record 15 of Set 8 | eyl
# Processing Record 16 of Set 8 | kuito
# Processing Record 17 of Set 8 | genhe
# Processing Record 18 of Set 8 | bauchi
# Processing Record 19 of Set 8 | pousat
# Processing Record 20 of Set 8 | sokol
# Processing Record 21 of Set 8 | xining
# Processing Record 22 of Set 8 | thinadhoo
# Processing Record 23 of Set 8 | alekseyevsk
# Processing Record 24 of Set 8 | sosnovo
# Processing Record 25 of Set 8 | opotiki
# Processing Record 26 of Set 8 | colares
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | tarbagatay
# Processing Record 29 of Set 8 | bhimunipatnam
# Processing Record 30 of Set 8 | ostersund
# Processing Record 31 of Set 8 | dzhebariki-khaya
# Processing Record 32 of Set 8 | ahipara
# Processing Record 33 of Set 8 | dolores
# Processing Record 34 of Set 8 | nezlobnaya
# Processing Record 35 of Set 8 | bako
# Processing Record 36 of Set 8 | itaituba
# Processing Record 37 of Set 8 | kasli
# Processing Record 38 of Set 8 | chicama
# Processing Record 39 of Set 8 | tiksi
# Processing Record 40 of Set 8 | san cristobal
# Processing Record 41 of Set 8 | taiyuan
# Processing Record 42 of Set 8 | siva
# Processing Record 43 of Set 8 | camargo
# Processing Record 44 of Set 8 | dalvik
# Processing Record 45 of Set 8 | champerico
# Processing Record 46 of Set 8 | ituni
# Processing Record 47 of Set 8 | drumheller
# Processing Record 48 of Set 8 | sirfa
# Processing Record 49 of Set 8 | mildura
# Processing Record 50 of Set 8 | vaitupu
# Processing Record 1 of Set 9 | chara
# Processing Record 2 of Set 9 | mulchen
# Processing Record 3 of Set 9 | baiyin
# Processing Record 4 of Set 9 | blackfalds
# Processing Record 5 of Set 9 | serebryansk
# Processing Record 6 of Set 9 | ugoofaaru
# Processing Record 7 of Set 9 | marquette
# Processing Record 8 of Set 9 | saint-malo
# Processing Record 9 of Set 9 | beyneu
# Processing Record 10 of Set 9 | bongandanga
# Processing Record 11 of Set 9 | kyabram
# Processing Record 12 of Set 9 | anloga
# Processing Record 13 of Set 9 | aquiraz
# Processing Record 14 of Set 9 | korla
# Processing Record 15 of Set 9 | xai-xai
# Processing Record 16 of Set 9 | nemuro
# Processing Record 17 of Set 9 | awjilah
# Processing Record 18 of Set 9 | tateyama
# Processing Record 19 of Set 9 | guanay
# Processing Record 20 of Set 9 | gewane
# Processing Record 21 of Set 9 | wagar
# Processing Record 22 of Set 9 | exeter
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | velizh
# Processing Record 25 of Set 9 | sobolevo
# Processing Record 26 of Set 9 | aguimes
# Processing Record 27 of Set 9 | te anau
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | moranbah
# Processing Record 30 of Set 9 | kharan
# Processing Record 31 of Set 9 | gat
# Processing Record 32 of Set 9 | kang
# Processing Record 33 of Set 9 | high prairie
# Processing Record 34 of Set 9 | kalengwa
# Processing Record 35 of Set 9 | anchorage
# Processing Record 36 of Set 9 | pandaria
# Processing Record 37 of Set 9 | bairiki
# Processing Record 38 of Set 9 | zhuhai
# Processing Record 39 of Set 9 | kirksville
# Processing Record 40 of Set 9 | dudinka
# Processing Record 41 of Set 9 | usinsk
# Processing Record 42 of Set 9 | rundu
# Processing Record 43 of Set 9 | yakeshi
# Processing Record 44 of Set 9 | harper
# Processing Record 45 of Set 9 | kudahuvadhoo
# Processing Record 46 of Set 9 | horasan
# Processing Record 47 of Set 9 | batagay-alyta
# Processing Record 48 of Set 9 | provideniya
# Processing Record 49 of Set 9 | sumbe
# Processing Record 50 of Set 9 | batsfjord
# Processing Record 1 of Set 10 | basti
# Processing Record 2 of Set 10 | warqla
# Processing Record 3 of Set 10 | mahibadhoo
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | terrace
# Processing Record 6 of Set 10 | springbok
# Processing Record 7 of Set 10 | bargal
# Processing Record 8 of Set 10 | mount isa
# Processing Record 9 of Set 10 | novorzhev
# Processing Record 10 of Set 10 | kaeo
# Processing Record 11 of Set 10 | ewa beach
# Processing Record 12 of Set 10 | georgetown
# Processing Record 13 of Set 10 | pasighat
# Processing Record 14 of Set 10 | ilo
# Processing Record 15 of Set 10 | santa maria
# Processing Record 16 of Set 10 | hambantota
# Processing Record 17 of Set 10 | tarudant
# Processing Record 18 of Set 10 | guangyuan
# Processing Record 19 of Set 10 | coahuayana
# Processing Record 20 of Set 10 | araouane
# Processing Record 21 of Set 10 | attawapiskat
# Processing Record 22 of Set 10 | grand gaube
# Processing Record 23 of Set 10 | chardara
# Processing Record 24 of Set 10 | boguchany
# Processing Record 25 of Set 10 | mae sot
# Processing Record 26 of Set 10 | alta floresta
# Processing Record 27 of Set 10 | kobojango
# Processing Record 28 of Set 10 | krasnoarmeysk
# Processing Record 29 of Set 10 | marau
# Processing Record 30 of Set 10 | gazojak
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | beisfjord
# Processing Record 33 of Set 10 | camana
# Processing Record 34 of Set 10 | walvis bay
# Processing Record 35 of Set 10 | lorengau
# Processing Record 36 of Set 10 | cabo rojo
# Processing Record 37 of Set 10 | roald
# Processing Record 38 of Set 10 | kodiak
# Processing Record 39 of Set 10 | hervey bay
# Processing Record 40 of Set 10 | ludvika
# Processing Record 41 of Set 10 | eirunepe
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | skibbereen
# Processing Record 44 of Set 10 | ixtapa
# Processing Record 45 of Set 10 | madera
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | lakes entrance
# Processing Record 48 of Set 10 | mihai bravu
# Processing Record 49 of Set 10 | verkhoyansk
# Processing Record 50 of Set 10 | namibe
# Processing Record 1 of Set 11 | ita
# Processing Record 2 of Set 11 | khani
# Processing Record 3 of Set 11 | ayan
# Processing Record 4 of Set 11 | wilmington
# Processing Record 5 of Set 11 | iskateley
# Processing Record 6 of Set 11 | jiddah
# Processing Record 7 of Set 11 | san jose
# Processing Record 8 of Set 11 | chumikan
# Processing Record 9 of Set 11 | champawat
# Processing Record 10 of Set 11 | ondarroa
# Processing Record 11 of Set 11 | dali
# Processing Record 12 of Set 11 | niltepec
# Processing Record 13 of Set 11 | quang ngai
# Processing Record 14 of Set 11 | krasnomayskiy
# Processing Record 15 of Set 11 | porbandar
# Processing Record 16 of Set 11 | morros
# Processing Record 17 of Set 11 | nacogdoches
# Processing Record 18 of Set 11 | snezhnogorsk
# Processing Record 19 of Set 11 | waverly
# Processing Record 20 of Set 11 | cabo san lucas
# Processing Record 21 of Set 11 | grand river south east
# Processing Record 22 of Set 11 | mahebourg
# Processing Record 23 of Set 11 | tidore
# Processing Record 24 of Set 11 | bandar-e lengeh
# Processing Record 25 of Set 11 | saint combs
# Processing Record 26 of Set 11 | fundao
# Processing Record 27 of Set 11 | barkot
# Processing Record 28 of Set 11 | xuanhua
# Processing Record 29 of Set 11 | amahai
# Processing Record 30 of Set 11 | saint austell
# Processing Record 31 of Set 11 | concordia
# Processing Record 32 of Set 11 | ambilobe
# Processing Record 33 of Set 11 | casma
# Processing Record 34 of Set 11 | yarkovo
# Processing Record 35 of Set 11 | kamenka
# Processing Record 36 of Set 11 | warora
# Processing Record 37 of Set 11 | leshukonskoye
# Processing Record 38 of Set 11 | shimoda
# Processing Record 39 of Set 11 | trelew
# Processing Record 40 of Set 11 | carlsbad
# Processing Record 41 of Set 11 | fort abbas
# Processing Record 42 of Set 11 | portland
# Processing Record 43 of Set 11 | kununurra
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | caravelas
# Processing Record 46 of Set 11 | shenkursk
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | malegaon
# Processing Record 49 of Set 11 | santa rosa
# Processing Record 50 of Set 11 | orzhytsya
# Processing Record 1 of Set 12 | stamsund
# Processing Record 2 of Set 12 | kupang
# Processing Record 3 of Set 12 | marzuq
# Processing Record 4 of Set 12 | yuncheng
# Processing Record 5 of Set 12 | beli potok
# Processing Record 6 of Set 12 | college
# Processing Record 7 of Set 12 | palmer
# Processing Record 8 of Set 12 | dvinskoy
# Processing Record 9 of Set 12 | springdale
# Processing Record 10 of Set 12 | makakilo city
# Processing Record 11 of Set 12 | soyo
# Processing Record 12 of Set 12 | maragogi
# Processing Record 13 of Set 12 | maldonado
# Processing Record 14 of Set 12 | strezhevoy
# Processing Record 15 of Set 12 | vila do maio
# Processing Record 16 of Set 12 | san vicente
# Processing Record 17 of Set 12 | saldanha
# Processing Record 18 of Set 12 | deputatskiy
# Processing Record 19 of Set 12 | halalo
# Processing Record 20 of Set 12 | morant bay
# Processing Record 21 of Set 12 | badiraguato
# Processing Record 22 of Set 12 | adrar
# Processing Record 23 of Set 12 | pinotepa nacional
# Processing Record 24 of Set 12 | puerto carreno
# Processing Record 25 of Set 12 | praia
# Processing Record 26 of Set 12 | rabat
# Processing Record 27 of Set 12 | shache
# Processing Record 28 of Set 12 | bagotville
# Processing Record 29 of Set 12 | rocha
# Processing Record 30 of Set 12 | orlik
# Processing Record 31 of Set 12 | veraval
# Processing Record 32 of Set 12 | lagos
# Processing Record 33 of Set 12 | padang
# Processing Record 34 of Set 12 | sao filipe
# Processing Record 35 of Set 12 | margate
# Processing Record 36 of Set 12 | makinsk
# Processing Record 37 of Set 12 | miri
# Processing Record 38 of Set 12 | kawambwa
# Processing Record 39 of Set 12 | gerede
# Processing Record 40 of Set 12 | narasapur
# Processing Record 41 of Set 12 | anahuac
# Processing Record 42 of Set 12 | vigrestad
# Processing Record 43 of Set 12 | albion
# Processing Record 44 of Set 12 | saint-joseph
# Processing Record 45 of Set 12 | cardston
# Processing Record 46 of Set 12 | nieuw nickerie
# Processing Record 47 of Set 12 | prijepolje
# Processing Record 48 of Set 12 | prilep
# Processing Record 49 of Set 12 | sibolga
# Processing Record 50 of Set 12 | balclutha
# Processing Record 1 of Set 13 | kampong chhnang
# Processing Record 2 of Set 13 | kokopo
# Processing Record 3 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 13 | cochrane
# Processing Record 5 of Set 13 | pulaski
# Processing Record 6 of Set 13 | mercedes
# Processing Record 7 of Set 13 | miguel auza
# Processing Record 8 of Set 13 | santa cruz
# Processing Record 9 of Set 13 | sioux lookout
# Processing Record 10 of Set 13 | oltina
# Processing Record 11 of Set 13 | sangueya
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | salinopolis
# Processing Record 14 of Set 13 | jinchang
# Processing Record 15 of Set 13 | linjiang
# Processing Record 16 of Set 13 | zambezi
# Processing Record 17 of Set 13 | isoka
# Processing Record 18 of Set 13 | novoagansk
# Processing Record 19 of Set 13 | itarema
# Processing Record 20 of Set 13 | ngunguru
# Processing Record 21 of Set 13 | paamiut
# Processing Record 22 of Set 13 | peniche
# Processing Record 23 of Set 13 | san quintin
# Processing Record 24 of Set 13 | chateaubelair
# Processing Record 25 of Set 13 | almaznyy
# Processing Record 26 of Set 13 | itupiranga
# Processing Record 27 of Set 13 | mama
# Processing Record 28 of Set 13 | lidkoping
# Processing Record 29 of Set 13 | cagliliog
# Processing Record 30 of Set 13 | itoman
# Processing Record 31 of Set 13 | mawlaik
# Processing Record 32 of Set 13 | iranshahr
# Processing Record 33 of Set 13 | la primavera
# Processing Record 34 of Set 13 | fabriano
# Processing Record 35 of Set 13 | shihezi
# Processing Record 36 of Set 13 | kiruna
# Processing Record 37 of Set 13 | bardiyah
# Processing Record 38 of Set 13 | deshna
# Processing Record 39 of Set 13 | milan
# Processing Record 40 of Set 13 | den helder
# Processing Record 41 of Set 13 | kushiro
# Processing Record 42 of Set 13 | challapata
# Processing Record 43 of Set 13 | tamiahua
# Processing Record 44 of Set 13 | shar
# Processing Record 45 of Set 13 | ilhabela
# Processing Record 46 of Set 13 | jijiga
# Processing Record 47 of Set 13 | suhbaatar
# Processing Record 48 of Set 13 | asosa
# Processing Record 49 of Set 13 | cairns
# Processing Record 50 of Set 13 | dongli
# Processing Record 1 of Set 14 | alanya
# Processing Record 2 of Set 14 | cuxhaven
# Processing Record 3 of Set 14 | ouadda
# Processing Record 4 of Set 14 | nanortalik
# Processing Record 5 of Set 14 | yaqui
# Processing Record 6 of Set 14 | yenagoa
# Processing Record 7 of Set 14 | grand-santi
# Processing Record 8 of Set 14 | mudon
# Processing Record 9 of Set 14 | arbroath
# Processing Record 10 of Set 14 | sharjah
# Processing Record 11 of Set 14 | labuhan
# Processing Record 12 of Set 14 | grootfontein
# Processing Record 13 of Set 14 | salym
# Processing Record 14 of Set 14 | calubcub
# Processing Record 15 of Set 14 | barillas
# Processing Record 16 of Set 14 | waukegan
# Processing Record 17 of Set 14 | jiuquan
# Processing Record 18 of Set 14 | niquelandia
# Processing Record 19 of Set 14 | qui nhon
# Processing Record 20 of Set 14 | saquena
# Processing Record 21 of Set 14 | udachnyy
# Processing Record 22 of Set 14 | plettenberg bay
# Processing Record 23 of Set 14 | grindavik
# Processing Record 24 of Set 14 | cadillac
# Processing Record 25 of Set 14 | montecristi
# Processing Record 26 of Set 14 | hobyo
# Processing Record 27 of Set 14 | sucre
# Processing Record 28 of Set 14 | enid
# Processing Record 29 of Set 14 | yuzhno-yeniseyskiy
# Processing Record 30 of Set 14 | marsa matruh
# Processing Record 31 of Set 14 | khandyga
# Processing Record 32 of Set 14 | jalu
# Processing Record 33 of Set 14 | belmonte
# Processing Record 34 of Set 14 | chapaevsk
# Processing Record 35 of Set 14 | qianan
# Processing Record 36 of Set 14 | solnechnyy
# Processing Record 37 of Set 14 | mangrol
# Processing Record 38 of Set 14 | pokhara
# Processing Record 39 of Set 14 | jaipur hat
# Processing Record 40 of Set 14 | port blair
# Processing Record 41 of Set 14 | talkha
# Processing Record 42 of Set 14 | novikovo
# Processing Record 43 of Set 14 | bilibino
# Processing Record 44 of Set 14 | ardistan
# Processing Record 45 of Set 14 | cariamanga
# Processing Record 46 of Set 14 | inongo
# Processing Record 47 of Set 14 | vila velha
# Processing Record 48 of Set 14 | tokur
# Processing Record 49 of Set 14 | eregli
# Processing Record 50 of Set 14 | phuket
# Processing Record 1 of Set 15 | barranco
# Processing Record 2 of Set 15 | odesskoye
# Processing Record 3 of Set 15 | inuvik
# Processing Record 4 of Set 15 | maple valley
# Processing Record 5 of Set 15 | sume
# Processing Record 6 of Set 15 | havelock
# Processing Record 7 of Set 15 | yar-sale
# Processing Record 8 of Set 15 | canico
# Processing Record 9 of Set 15 | awbari
# Processing Record 10 of Set 15 | lompoc
# Processing Record 11 of Set 15 | rawson
# Processing Record 12 of Set 15 | de-kastri
# Processing Record 13 of Set 15 | malindi
# Processing Record 14 of Set 15 | mirador
# Processing Record 15 of Set 15 | shahrud
# Processing Record 16 of Set 15 | kumluca
# Processing Record 17 of Set 15 | valdivia
# Processing Record 18 of Set 15 | altay
# Processing Record 19 of Set 15 | newtownards
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | havre-saint-pierre
# Processing Record 22 of Set 15 | kasempa
# Processing Record 23 of Set 15 | shitanjing
# Processing Record 24 of Set 15 | meyungs
# Processing Record 25 of Set 15 | boyolangu
# Processing Record 26 of Set 15 | matagami
# Processing Record 27 of Set 15 | aljezur
# Processing Record 28 of Set 15 | alyangula
# Processing Record 29 of Set 15 | acari
# Processing Record 30 of Set 15 | valentin gomez farias
# Processing Record 31 of Set 15 | sulangan
# Processing Record 32 of Set 15 | belle glade
# Processing Record 33 of Set 15 | aguada de pasajeros
# Processing Record 34 of Set 15 | atasu
# Processing Record 35 of Set 15 | mayskiy
# Processing Record 36 of Set 15 | pericos
# Processing Record 37 of Set 15 | katsuura
# Processing Record 38 of Set 15 | tahta
# Processing Record 39 of Set 15 | pochutla
# Processing Record 40 of Set 15 | grand centre
# Processing Record 41 of Set 15 | hami
# Processing Record 42 of Set 15 | loreto
# Processing Record 43 of Set 15 | tezu
# Processing Record 44 of Set 15 | akyab
# Processing Record 45 of Set 15 | marienburg
# Processing Record 46 of Set 15 | sao joao da barra
# Processing Record 47 of Set 15 | lons-le-saunier
# Processing Record 48 of Set 15 | penzance
# Processing Record 49 of Set 15 | gunjur
# Processing Record 50 of Set 15 | kabanjahe
# Processing Record 1 of Set 16 | hvammstangi
# Processing Record 2 of Set 16 | bundaberg
# Processing Record 3 of Set 16 | charleston
# Processing Record 4 of Set 16 | gawler
# Processing Record 5 of Set 16 | crib point
# Processing Record 6 of Set 16 | nguiu
# Processing Record 7 of Set 16 | mitu
# Processing Record 8 of Set 16 | altamira
# Processing Record 9 of Set 16 | arenal
# Processing Record 10 of Set 16 | broken hill
# Processing Record 11 of Set 16 | port keats
# Processing Record 12 of Set 16 | simao
# Processing Record 13 of Set 16 | fuerte olimpo
# Processing Record 14 of Set 16 | kelapa sawit
# Processing Record 15 of Set 16 | lillooet
# Processing Record 16 of Set 16 | kuala terengganu
# Processing Record 17 of Set 16 | aksarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#       City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Aksarka  66.5606  67.7975    -18.81       100          98        6.33
#
#   Country                 Date
# 0      RU  2022-01-30 01:46:01

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
